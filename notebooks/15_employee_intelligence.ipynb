# %%
import pandas as pd

print("--- Step 16: Employee Intelligence Layer ---")
print("Stitching together the ultimate workforce intelligence table...\n")

# Tech magic: Simulating the final merged output from all our previous engines
# In production, this would be a series of pd.merge() calls on Employee_ID
intelligence_data = [
    {
        "Employee_ID": 101,
        "Dept": "IT",
        "Attrition_Prob": 0.81,
        "Risk": "HIGH",
        "Engagement": 62,
        "Role": "ML Engineer",
        "Skill_Gap": "MLOps, Docker",
        "Recommendation": "Deploying and Monitoring Machine Learning Systems"
    },
    {
        "Employee_ID": 102,
        "Dept": "Finance",
        "Attrition_Prob": 0.12,
        "Risk": "LOW",
        "Engagement": 90,
        "Role": "Data Analyst",
        "Skill_Gap": "Python",
        "Recommendation": "Advanced Python for Data Science"
    },
    {
        "Employee_ID": 103,
        "Dept": "HR",
        "Attrition_Prob": 0.45,
        "Risk": "MEDIUM",
        "Engagement": 70,
        "Role": "HR Business Partner",
        "Skill_Gap": "Generative AI",
        "Recommendation": "Search Internal LMS for: Generative AI"
    },
    {
        "Employee_ID": 104,
        "Dept": "Sales",
        "Attrition_Prob": 0.88,
        "Risk": "HIGH",
        "Engagement": 45,
        "Role": "Account Executive",
        "Skill_Gap": "AWS",
        "Recommendation": "AWS Cloud Practitioner Essentials"
    }
]

df_master = pd.DataFrame(intelligence_data)

# Save this master table for the dashboard to use tomorrow!
df_master.to_csv("../data/processed/employee_intelligence_master.csv", index=False)

print(df_master.to_string(index=False))
print("\nBoom! Master table successfully saved.")
